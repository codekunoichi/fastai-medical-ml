# %%
import fastai.vision.all
print(fastai.__version__)
# Out:
# 2.8.5

# %%
fastai.__file__
# Out:
# '/Users/rumpagiri/Projects/fastai-medical-ml/myenv/lib/python3.12/site-packages/fastai/__init__.py'

# %%
import sys
print(sys.executable)
# Out:
# /Users/rumpagiri/Projects/fastai-medical-ml/myenv/bin/python
